# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/preprocessed_data.csv")

display(df.head())

missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
#    Funding Rounds  Investment Amount (USD)  Number of Investors  \
# 0        0.861087                -0.786995             1.713896
# 1       -1.198601                 0.228941             0.732845
# 2        1.547650                 0.599493             0.943070
# 3       -0.168757                 1.120103             1.293446
# 4        1.204369                -0.569304             1.573746
#
#    Growth Rate (%)  Startup Age  Industry   Country  \
# 0        -0.444897    -0.066235 -0.684392  0.176717
# 1         0.061029     0.805276  1.495478  1.207736
# 2         1.573290    -0.647242  0.187556  0.864063
# 3        -1.649366    -1.373501  0.623530 -0.166956
# 4         1.600527     0.079017  0.187556  0.520390
#
#    Investment-to-Valuation Ratio  Funding Rounds per Investor  \
# 0                      -1.152166                    -0.325267
# 1                      -0.093331                    -0.430548
# 2                      -1.054470                    -0.228086
# 3                      -0.200349                    -0.372002
# 4                      -0.851432                    -0.297547
#
#    Growth-Adjusted Investment  Valuation (USD)
# 0                   -0.685248     6.621448e+09
# 1                    0.205443     8.363214e+09
# 2                    1.779499     1.548270e+10
# 3                   -0.987692     1.268253e+10
# 4                    0.309915     6.887966e+09
# Missing Values:
#  Funding Rounds                   0
# Investment Amount (USD)          0
# Number of Investors              0
# Growth Rate (%)                  0
# Startup Age                      0
# Industry                         0
# Country                          0
# Investment-to-Valuation Ratio    0
# Funding Rounds per Investor      0
# Growth-Adjusted Investment       0
# Valuation (USD)                  0
# dtype: int64

# %%
print("\nSummary Statistics:\n", df.describe())

plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()


plt.figure(figsize=(8, 5))
sns.histplot(df["Valuation (USD)"], bins=50, kde=True)
plt.xlabel("Startup Valuation (USD)")
plt.ylabel("Frequency")
plt.title("Distribution of Startup Valuation")
plt.show()


sns.pairplot(df, diag_kind="kde")
plt.show()
# Out:
# Summary Statistics:
#         Funding Rounds  Investment Amount (USD)  Number of Investors  \
# count    5.000000e+03             5.000000e+03         5.000000e+03
# mean    -2.700062e-17             3.694822e-17        -1.158185e-16
# std      1.000100e+00             1.000100e+00         1.000100e+00
# min     -1.541883e+00            -1.724071e+00        -1.719782e+00
# 25%     -8.553200e-01            -8.668321e-01        -8.788815e-01
# 50%      1.745243e-01             3.558836e-03        -3.798069e-02
# 75%      8.610871e-01             8.319378e-01         8.729952e-01
# max      1.547650e+00             1.786946e+00         1.713896e+00
#
#        Growth Rate (%)   Startup Age      Industry       Country  \
# count     5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean      1.229239e-16  6.252776e-17  3.055334e-17 -7.105427e-17
# std       1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min      -1.727337e+00 -1.664005e+00 -1.556340e+00 -1.541649e+00
# 25%      -8.772135e-01 -9.377456e-01 -6.843919e-01 -8.543026e-01
# 50%       2.194390e-03 -6.623482e-02  1.875560e-01  1.767167e-01
# 75%       8.631774e-01  8.052760e-01  1.059504e+00  8.640629e-01
# max       1.742407e+00  1.676787e+00  1.495478e+00  1.551409e+00
#
#        Investment-to-Valuation Ratio  Funding Rounds per Investor  \
# count                   5.000000e+03                 5.000000e+03
# mean                   -2.330580e-16                 6.927792e-17
# std                     1.000100e+00                 1.000100e+00
# min                    -1.165439e+00                -4.663876e-01
# 25%                    -8.279595e-01                -3.713474e-01
# 50%                    -3.030134e-01                -2.705472e-01
# 75%                     6.130439e-01                -6.654690e-02
# max                     2.606689e+00                 9.593470e+00
#
#        Growth-Adjusted Investment  Valuation (USD)
# count                5.000000e+03     5.000000e+03
# mean                 5.684342e-17     7.971059e+09
# std                  1.000100e+00     5.479487e+09
# min                 -1.166298e+00     1.722547e+06
# 25%                 -8.185110e-01     3.598305e+09
# 50%                 -2.848661e-01     7.002304e+09
# 75%                  5.854665e-01     1.147676e+10
# max                  3.452827e+00     2.470906e+10
